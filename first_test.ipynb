# %%
from torchvision import datasets
from torchvision.transforms import ToTensor
from torch.utils.data import DataLoader
from torch import nn
import torch

# %% [markdown]
# ### Database import

# %%
train_data = datasets.MNIST(
    root = 'data',
    train = True,                         
    transform = ToTensor(), 
    download = True,            
)
test_data = datasets.MNIST(
    root = 'data', 
    train = False, 
    transform = ToTensor()
)

# %%
# batch_size = 100
# n_iters = 3000
# num_epochs = n_iters / (len(train_data) / batch_size)
num_epochs = 50

train_dataloader = torch.utils.data.DataLoader(train_data, 
                                          batch_size=100, 
                                          shuffle=True)
    
test_dataloader = torch.utils.data.DataLoader(test_data, 
                                          batch_size=100, 
                                          shuffle=False)

# %%
print(len(train_data))
print(len(train_dataloader))
# Out:
# 60000
# 600

# %%
# device = "cuda" if torch.cuda.is_available() else "cpu"

class NormalNN(torch.nn.Module):
    def __init__(self):
        super().__init__()
        
        self.network = torch.nn.Sequential(
            torch.nn.Linear(28*28, 25),
            torch.nn.ReLU(),
            torch.nn.Linear(25, 35),
            torch.nn.ReLU(),
            torch.nn.Linear(35, 10)
        )
        
    def forward(self, x):
        out = network(x)
        return out
    
model = NormalNN()

# %%
criterion = torch.nn.CrossEntropyLoss()
optimizer = torch.optim.SGD(model.parameters(), lr=1e-3) # lr = learning rate

def train(train_dataloader, test_dataloader, model, criterion, optimizer):
    # size = len(train_dataloader.dataset)
    print(len(train_dataloader))
    for epoch in range(num_epochs):
        for batch, (X, y) in enumerate(train_dataloader):
            X = X.view(X.size(0), -1)
#             print(batch)
           # X, y = X.to(device), y.to(device)

            X = X.requires_grad_()
            optimizer.zero_grad()


            # Compute prediction error
            pred = model(X)
            loss = criterion(pred, y)

            # Backpropagation
            loss.backward()
            optimizer.step()

            if batch % 1000 == 0:
#                 loss = loss.item() # [0,1]
#                 print(f"loss: {loss:>7f} ")
                
                correct = 0
                total = 0
                
                # Iterate through test dataset
                for images, labels in test_dataloader:
                    images = images.view(images.size(0), -1)
                    
                    # Load images
                    images = images.requires_grad_()

                    outputs = model(images)

                    # Get predictions from the maximum value
                    _, predicted = torch.max(outputs.data, 1)
                    
                    # Total number of labels
                    total += labels.size(0)
                    correct += (predicted == labels).sum()

                accuracy = 100 * correct / total

                # Print Loss
                print('Iteration: {}. Loss: {}. Accuracy: {}'.format(batch, loss.item(), accuracy))


train(train_dataloader, test_dataloader, model.network, criterion, optimizer)

# epochs = 3
# for t in range(epochs):
#     print(f"Epoch {t+1}\n-------------------------------")
#     train(train_dataloader, model, criterion, optimizer)
#     #test(test_dataloader, model, loss_fn)
# Out:
# 600
# Iteration: 0. Loss: 2.3309695720672607. Accuracy: 8.600000381469727
# Iteration: 0. Loss: 2.3035051822662354. Accuracy: 9.34000015258789
# Iteration: 0. Loss: 2.292576551437378. Accuracy: 13.699999809265137
# Iteration: 0. Loss: 2.26487135887146. Accuracy: 16.979999542236328
# Iteration: 0. Loss: 2.242889404296875. Accuracy: 18.389999389648438
# Iteration: 0. Loss: 2.2138240337371826. Accuracy: 26.959999084472656
# Iteration: 0. Loss: 2.1658735275268555. Accuracy: 34.84000015258789
# Iteration: 0. Loss: 2.087245464324951. Accuracy: 37.439998626708984
# Iteration: 0. Loss: 2.035390853881836. Accuracy: 46.54999923706055
# Iteration: 0. Loss: 1.9214372634887695. Accuracy: 52.439998626708984
# Iteration: 0. Loss: 1.7789428234100342. Accuracy: 55.130001068115234
# Iteration: 0. Loss: 1.5741019248962402. Accuracy: 58.459999084472656
# Iteration: 0. Loss: 1.5059897899627686. Accuracy: 62.5099983215332
# Iteration: 0. Loss: 1.1925804615020752. Accuracy: 66.7300033569336
# ...

# %%
del(modelTmp)
modelTmp = ClassicModel()

def learnNetwork(model, num_epochs ,learning_rate=0.05):
    iter = 0
    optimizer = torch.optim.SGD(model.parameters(), lr=learning_rate)
    for epoch in range(num_epochs):
        start_time = timer.time()
        for i, (images, labels) in enumerate(train_loader):
            images = images.view(images.size(0), -1)
            
            images = images.requires_grad_()
            optimizer.zero_grad()

            # Forward pass to get output/logits
            outputs = model(images)

            # Calculate Loss: softmax --> cross entropy loss
            loss = criterion(outputs, labels)
            loss.backward()

            # Updating parameters
            optimizer.step()

            iter += 1
            if iter % 100 == 0:
                # Calculate Accuracy         
                correct = 0
                total = 0
                
                # Iterate through test dataset
                for images, labels in test_loader:
                    images = images.view(images.size(0), -1)
                    
                    # Load images
                    images = images.requires_grad_()

                    outputs = model(images)

                    # Get predictions from the maximum value
                    _, predicted = torch.max(outputs.data, 1)
                    
                    # Total number of labels
                    total += labels.size(0)
                    correct += (predicted == labels).sum()
                    break

                accuracy = 100 * correct / total

                # Print Loss
                print('Iteration: {}. Loss: {}. Accuracy: {}'.format(iter, loss.item(), accuracy))
                print('learning time is: {}'.format(timer.time() - start_time))
                sysTime = %time
                print(sysTime)
                
learnNetwork(modelTmp.network, 2 ,learning_rate=0.05)
